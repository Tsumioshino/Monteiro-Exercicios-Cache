# %%
#E5.5; E5.6; E5.7
from math import log2
K = 2**10; M = 2**20
t_mp = 16*M  
t_cache = 32*K #Bytes. Note que quando o total de BITS é requerido, multiplica-se esse valor por 8.
t_linha = 8
n_blocos = t_mp/t_linha
n_linhas = t_cache/t_linha
bits_tag = log2(n_blocos)
bits_celula = log2(t_linha)
bits_cache = bits_tag + bits_celula
end_linha_des = None
if end_linha_des is not None:
    del(end_linha_des[-1:-int(bits_celula)-1:-1])
    end_linha_des = ''.join(end_linha_des)
print(f"""O formato do endereço interpretado pelo sistema de controle da cache é: 
---------- {bits_cache} bits-----------
BLOCO/TAG: {bits_tag} CÉLULA: {bits_celula}
O total de bits necessários para essa memória cache é de: {(log2(n_blocos)*n_linhas)+(t_cache*8)}
O endereço da linha desejada é: {end_linha_des}""")
# Out:
# O formato do endereço interpretado pelo sistema de controle da cache é:
# ---------- 24.0 bits-----------
# BLOCO/TAG: 21.0 CÉLULA: 3.0
# O total de bits necessários para essa memória cache é de: 348160.0
# O endereço da linha desejada é: None

# %%
#E5.5; E5.6; E5.7
from math import log2
K = 2**10; M = 2**20
t_mp = 64*M  
t_linha = 16
n_linhas = 2*K
t_cache = t_linha*n_linhas #Bytes. Note que quando o total de BITS é requerido, multiplica-se esse valor por 8.
n_blocos = t_mp/t_linha
bits_tag = log2(n_blocos)
bits_celula = log2(t_linha)
bits_cache = bits_tag + bits_celula
end_linha_des = None
if end_linha_des is not None:
    del(end_linha_des[-1:-int(bits_celula)-1:-1])
    end_linha_des = ''.join(end_linha_des)
print(f"""O formato do endereço interpretado pelo sistema de controle da cache é: 
---------- {bits_cache} bits-----------
BLOCO/TAG: {bits_tag} CÉLULA: {bits_celula}
O total de bits necessários para essa memória cache é de: {(log2(n_blocos)*n_linhas)+(t_cache*8)}
O endereço da linha desejada é: {end_linha_des}""")
# Out:
# O formato do endereço interpretado pelo sistema de controle da cache é:
# ---------- 26.0 bits-----------
# BLOCO/TAG: 22.0 CÉLULA: 4.0
# O total de bits necessários para essa memória cache é de: 307200.0
# O endereço da linha desejada é: None

# %%
#E5.5; E5.6; E5.7
from math import log2
K = 2**10; M = 2**20 
t_mp = 256*M #3FC92B6 = 28 BITS; E = 28; 2**E = N; N = 2**28 = (2**8)*(2**20) = 256MB
t_cache = 64*K #Bytes. Note que quando o total de BITS é requerido, multiplica-se esse valor por 8.
t_linha = 32
n_blocos = t_mp/t_linha
n_linhas = t_cache/t_linha
bits_tag = log2(n_blocos)
bits_celula = log2(t_linha)
bits_cache = bits_tag + bits_celula
end_linha_des = list('0011111111001001001010110110') #3FC92B6 = 0011 1111 1100 1001 0010 1011 0110
if end_linha_des is not None:
    del(end_linha_des[-1:-int(bits_celula)-1:-1])
    end_linha_des = ''.join(end_linha_des)
print(f"""O formato do endereço interpretado pelo sistema de controle da cache é: 
---------- {bits_cache} bits-----------
BLOCO/TAG: {bits_tag} CÉLULA: {bits_celula}
O total de bits necessários para essa memória cache é de: {(log2(n_blocos)*n_linhas)+(t_cache*8)}
O endereço da linha desejada é: {end_linha_des}""")
# Out:
# O formato do endereço interpretado pelo sistema de controle da cache é:
# ---------- 28.0 bits-----------
# BLOCO/TAG: 23.0 CÉLULA: 5.0
# O total de bits necessários para essa memória cache é de: 571392.0
# O endereço da linha desejada é: 00111111110010010010101
